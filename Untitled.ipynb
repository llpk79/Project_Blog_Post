# %%
import eli5
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from category_encoders import OrdinalEncoder
from eli5.sklearn import PermutationImportance
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle
from xgboost import XGBRFClassifier, XGBClassifier

# %%
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
test = pd.read_stata("C:\\Users\Paul\PycharmProjects\BlogPost\data\WA_BRFSS_11to17_B.dta",
                     convert_missing=False)

# %%
test.head()
# Out:
#    SAMPLE    year      qstver  qstver2  qstlang       dispcode         seqno  \
# 0     NaN  2011.0  Cell Phone     20.0  English  Full Complete  2.011000e+09
# 1     NaN  2011.0  Cell Phone     20.0  English  Full Complete  2.011000e+09
# 2     NaN  2011.0  Cell Phone     20.0  English  Full Complete  2.011000e+09
# 3     NaN  2011.0  Cell Phone     20.0  English  Full Complete  2.011000e+09
# 4     NaN  2011.0  Cell Phone     20.0  English  Full Complete  2.011000e+09
#
#        _ststr cstate  numadult  hhadult  DEMO     sex   age  agegp_wa  \
# 0  18153999.0     No       NaN      NaN   NaN    Male  58.0       NaN
# 1  18153999.0     No       NaN      NaN   NaN  Female  26.0       NaN
# 2  18153999.0     No       NaN      NaN   NaN    Male  26.0       NaN
# 3  18153999.0     No       NaN      NaN   NaN    Male  30.0       NaN
# 4  18153999.0     No       NaN      NaN   NaN    Male  20.0       NaN
#
#   _ageg5yr _age65yr _age_g     _race          _prace         _prace1 _mrace  \
# 0    55-59    18-64  55-64  White NH           White           White  White
# 1    25-29    18-64  25-34  White NH           White           White  White
# 2    25-29    18-64  25-34  Hispanic           White           White  White
# 3    30-34    18-64  25-34  Multi NH  None preferred  None preferred  Multi
# 4    18-24    18-64  18-24  Asian NH           Asian           Asian  Asian
#
#   _mrace1     race2  _racegr2 _racegr3 _m_race hispanc2 hispanc3 _hispanc  \
# 0     NaN  White NH  White NH      NaN     NaN       No               NaN
# 1     NaN  White NH  White NH      NaN     NaN       No               NaN
# 2     NaN  Hispanic  Hispanic      NaN     NaN      Yes               NaN
# 3     NaN  Multi NH  Multi NH      NaN     NaN       No               NaN
# 4     NaN  Asian NH  Other NH      NaN     NaN       No               NaN
#
#   veteran3               marital marital_wa  children _chldcnt         educa  \
# 0       No              Divorced        NaN      88.0     None  College Grad
# 1       No  Member Unmarried Cpl        NaN      88.0     None       HS Grad
# 2      Yes  Member Unmarried Cpl        NaN       3.0    Three  Some College
# 3      Yes               Married        NaN       1.0      One  College Grad
# 4       No         Never Married        NaN      88.0     None       HS Grad
#
#         _educag              employ employ1 occ11 ind11 jobactiv emplinjm  \
# 0  College grad  Employed for wages     NaN   NaN   NaN      NaN      NaN
# 1       HS grad  Employed for wages     NaN   NaN   NaN      NaN      NaN
# 2  Some college  Employed for wages     NaN   NaN   NaN      NaN      NaN
# 3  College grad  Employed for wages     NaN   NaN   NaN      NaN      NaN
# 4       HS grad             Student     NaN   NaN   NaN      NaN      NaN
#
#    income2 income_wa  _incomg  weight2  height3  htin4   htm4    wtkg3  \
# 0     $75+       NaN     50k+    300.0    603.0   75.0  191.0  13608.0
# 1  $15-20K       NaN  $15-25K    150.0    500.0   60.0  152.0   6804.0
# 2     $75+       NaN     50k+    165.0    506.0   66.0  168.0   7484.0
# 3     $75+       NaN     50k+    230.0    603.0   75.0  191.0  10433.0
# 4     $75+       NaN     50k+    135.0    507.0   67.0  170.0   6123.0
#
#     _bmi5 _bmi5cat _rfbmi5     ctycode1       LHJ  ACH zipcode zipcode1  \
# 0  3750.0    Obese     Yes      Refused     Clark  NaN   98683
# 1  2929.0     Over     Yes  Other State     Clark  NaN   98607
# 2  2663.0     Over     Yes      Refused    Kitsap  NaN   98312
# 3  2875.0     Over     Yes      Refused  Thurston  NaN   98516
# 4  2114.0   Normal      No         King      King  NaN   77777
#
#   renthom1 build1  build2 sexorien sexorin1 sxorient trnsgndr pregnant  \
# 0    Other    NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 1     Rent    NaN     NaN      NaN      NaN      NaN      NaN       No
# 2     Rent    NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 3      Own    NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 4      Own    NaN     NaN      NaN      NaN      NaN      NaN      NaN
#
#   internet  GENHLTH    genhlth _rfhlth  physhlth  _phys14d  menthlth  \
# 0      NaN      NaN       Good     Yes      88.0       NaN      88.0
# 1      NaN      NaN       Good     Yes       2.0       NaN      26.0
# 2      NaN      NaN  Excellent     Yes       2.0       NaN      88.0
# 3      NaN      NaN  Excellent     Yes      88.0       NaN      88.0
# 4      NaN      NaN  Excellent     Yes      88.0       NaN       2.0
#
#    _ment14d  poorhlth  sleptim1  ACCESS hlthplan hlthpln1 _hcvu651 persdoc2  \
# 0       NaN       NaN       NaN     NaN      Yes      NaN      Yes       No
# 1       NaN      88.0       NaN     NaN       No      NaN       No       No
# 2       NaN      88.0       NaN     NaN      Yes      NaN      Yes       No
# 3       NaN       NaN       NaN     NaN      Yes      NaN      Yes      Yes
# 4       NaN      88.0       NaN     NaN      Yes      NaN      Yes      Yes
#
#   medcost   checkup1 medicare hlthcvrg hlthcvr1  drvisits delaymed delaymda  \
# 0      No  1-2 years      NaN               NaN       NaN      NaN      NaN
# 1     Yes   5+ years      NaN               NaN       NaN      NaN      NaN
# 2      No  Past Year      NaN               NaN       NaN      NaN      NaN
# 3      No  Past Year      NaN               NaN       NaN      NaN      NaN
# 4      No  Past Year      NaN               NaN       NaN      NaN      NaN
#
#   delaymdb delaymdc delaymdd delaymde delaymdf delaymdg  CARDIO bphigh4  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN     NaN      No
# 1      NaN      NaN      NaN      NaN      NaN      NaN     NaN      No
# 2      NaN      NaN      NaN      NaN      NaN      NaN     NaN      No
# 3      NaN      NaN      NaN      NaN      NaN      NaN     NaN      No
# 4      NaN      NaN      NaN      NaN      NaN      NaN     NaN      No
#
#   bpmeds _rfhype5 bloodcho    cholchk cholchk1 toldhi2  \
# 0    NaN       No      Yes  Past Year      NaN     Yes
# 1    NaN       No       No        NaN      NaN     NaN
# 2    NaN       No      Yes  2-5 years      NaN      No
# 3    NaN       No       No        NaN      NaN     NaN
# 4    NaN       No      Yes  1-2 years      NaN      No
#
#                   _cholchk  _cholch1 _rfchol  _rfchol1  CHRONIC cvdinfr4  \
# 0  Checked in Past 5 Years       NaN      No       NaN      NaN       No
# 1            Never Checked       NaN     NaN       NaN      NaN       No
# 2  Checked in Past 5 Years       NaN     Yes       NaN      NaN       No
# 3            Never Checked       NaN     NaN       NaN      NaN       No
# 4  Checked in Past 5 Years       NaN     Yes       NaN      NaN       No
#
#   cvdcrhd4 _michd cvdstrk3 asthma3 asthnow _ltasth1 _casthm1 _asthms1  \
# 0       No    NaN       No      No     NaN       No       No    Never
# 1       No    NaN       No      No     NaN       No       No    Never
# 2       No    NaN       No      No     NaN       No       No    Never
# 3       No    NaN       No      No     NaN       No       No    Never
# 4       No    NaN       No      No     NaN       No       No    Never
#
#   chcscncr chcocncr cncrdiff  cncrage cncrtyp1 chccopd1 havarth3 _drdxar1  \
# 0       No      Yes      NaN      NaN      NaN       No       No       No
# 1       No       No      NaN      NaN      NaN       No       No       No
# 2       No       No      NaN      NaN      NaN       No       No       No
# 3       No       No      NaN      NaN      NaN       No       No       No
# 4       No       No      NaN      NaN      NaN       No       No       No
#
#   lmtjoin3 arthdis2 arthsocl  joinpain  joinpai1 _lmtact1 _lmtwrk1 _lmtscl1  \
# 0      NaN      NaN      NaN       NaN       NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN       NaN       NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN       NaN       NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN       NaN       NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN       NaN       NaN      NaN      NaN      NaN
#
#   addepev2 chckidny pdiabtst prediab1 diabete3  diabage2 insulin  bldsugar  \
# 0       No       No      NaN      NaN       No       NaN     NaN       NaN
# 1       No       No      NaN      NaN       No       NaN     NaN       NaN
# 2       No       No      NaN      NaN       No       NaN     NaN       NaN
# 3       No       No      NaN      NaN       No       NaN     NaN       NaN
# 4       No       No      NaN      NaN       No       NaN     NaN       NaN
#
#    feetchk2  doctdiab  chkhemo3  feetchk  eyeexam  diabeye diabedu  ORAL_HLTH  \
# 0       NaN       NaN       NaN      NaN      NaN      NaN     NaN        NaN
# 1       NaN       NaN       NaN      NaN      NaN      NaN     NaN        NaN
# 2       NaN       NaN       NaN      NaN      NaN      NaN     NaN        NaN
# 3       NaN       NaN       NaN      NaN      NaN      NaN     NaN        NaN
# 4       NaN       NaN       NaN      NaN      NaN      NaN     NaN        NaN
#
#   dentlins lastden3 rmvteth3 tethache _exteth2 _alteth2 _denvst2  DISABILITY  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN         NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN         NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN         NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN         NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN         NaN
#
#   qlactlm2 useequip deaf blind decide diffwalk diffdres diffalon  SMOKING  \
# 0       No       No  NaN   NaN    NaN      NaN      NaN      NaN      NaN
# 1       No       No  NaN   NaN    NaN      NaN      NaN      NaN      NaN
# 2       No       No  NaN   NaN    NaN      NaN      NaN      NaN      NaN
# 3       No       No  NaN   NaN    NaN      NaN      NaN      NaN      NaN
# 4       No       No  NaN   NaN    NaN      NaN      NaN      NaN      NaN
#
#   smoke100    smokday2 stopsmk2  quitadv   lastsmk1 lastsmk2  \
# 0       No         NaN      NaN      NaN        NaN      NaN
# 1      Yes   Every Day       No      NaN        NaN      NaN
# 2      Yes  Not at all      NaN      NaN  1-5 years      NaN
# 3       No         NaN      NaN      NaN        NaN      NaN
# 4       No         NaN      NaN      NaN        NaN      NaN
#
#               _smoker3 _rfsmok3  ahe2     usenow3  hookah  ecigs  ecigs1  \
# 0         Never Smoked       No   NaN  Not at all     NaN    NaN     NaN
# 1  Current - Every Day      Yes   NaN  Not at all     NaN    NaN     NaN
# 2        Former Smoker       No   NaN  Not at all     NaN    NaN     NaN
# 3         Never Smoked       No   NaN  Not at all     NaN    NaN     NaN
# 4         Never Smoked       No   NaN  Not at all     NaN    NaN     NaN
#
#   ecigaret ecignow _ecigsts _curecig  ALCOHOL alcday5  avedrnk2  drnk3ge5  \
# 0      NaN     NaN      NaN      NaN      NaN   107.0       2.0       4.0
# 1      NaN     NaN      NaN      NaN      NaN   888.0       NaN       NaN
# 2      NaN     NaN      NaN      NaN      NaN   230.0       2.0      88.0
# 3      NaN     NaN      NaN      NaN      NaN   201.0       1.0      88.0
# 4      NaN     NaN      NaN      NaN      NaN   202.0       3.0      88.0
#
#    maxdrnks  drliq  aveliq  drnkdri2 drnkany5  drocdy3_ _rfbing5  _drnkdy4  \
# 0       4.0    NaN     NaN       NaN      Yes     100.0      Yes     200.0
# 1       NaN    NaN     NaN       NaN       No       0.0       No       0.0
# 2       2.0    NaN     NaN       NaN      Yes     100.0       No     200.0
# 3       1.0    NaN     NaN       NaN      Yes       3.0       No       3.0
# 4       5.0    NaN     NaN       NaN      Yes       7.0       No      20.0
#
#    _drnkmo4  _drnkwek _rfdrhv4 _rfdrhv5 _rfdrmn4 _rfdrwm4  FRUITVEG  fruitju1  \
# 0      60.0       NaN       No      NaN       No      NaN       NaN     555.0
# 1       0.0       NaN       No      NaN      NaN       No       NaN     302.0
# 2      60.0       NaN       No      NaN       No      NaN       NaN     101.0
# 3       1.0       NaN       No      NaN       No      NaN       NaN     302.0
# 4       6.0       NaN       No      NaN       No      NaN       NaN     310.0
#
#    fruitju2  fruit1  fruit2  fvbeans  fvgreen  fvgreen1  fvorang  vegetab1  \
# 0       NaN   201.0     NaN    204.0    205.0       NaN    204.0     203.0
# 1       NaN   301.0     NaN    555.0    303.0       NaN    302.0     306.0
# 2       NaN   555.0     NaN    302.0    304.0       NaN    555.0     201.0
# 3       NaN   102.0     NaN    310.0    103.0       NaN    101.0     103.0
# 4       NaN   101.0     NaN    305.0    320.0       NaN    305.0     101.0
#
#    vegetab2  frenchf1  potatoe1  ftjuda1_  ftjuda2_  frutda1_  frutda2_  \
# 0       NaN       NaN       NaN       0.0       NaN      14.0       NaN
# 1       NaN       NaN       NaN       7.0       NaN       3.0       NaN
# 2       NaN       NaN       NaN     100.0       NaN       0.0       NaN
# 3       NaN       NaN       NaN       7.0       NaN     200.0       NaN
# 4       NaN       NaN       NaN      33.0       NaN     100.0       NaN
#
#    beanday_  grenday_  grenda1_  orngday_  vegeda1_  vegeda2_  frnchda_  \
# 0      57.0      71.0       NaN      57.0      43.0       NaN       NaN
# 1       0.0      10.0       NaN       7.0      20.0       NaN       NaN
# 2       7.0      13.0       NaN       0.0      14.0       NaN       NaN
# 3      33.0     300.0       NaN     100.0     300.0       NaN       NaN
# 4      17.0      67.0       NaN      17.0     100.0       NaN       NaN
#
#    potada1_ _misfrtn _misfrt1 _misvegn _misveg1      _frtresp _frtres1  \
# 0       NaN     None      NaN     None      NaN  None Missing      NaN
# 1       NaN     None      NaN     None      NaN  None Missing      NaN
# 2       NaN     None      NaN     None      NaN  None Missing      NaN
# 3       NaN     None      NaN     None      NaN  None Missing      NaN
# 4       NaN     None      NaN     None      NaN  None Missing      NaN
#
#        _vegresp _vegres1  _frutsum  _frutsu1  _vegesum  _vegesu1 _frtlt1  \
# 0  None Missing      NaN      14.0       NaN     228.0       NaN     NaN
# 1  None Missing      NaN      10.0       NaN      37.0       NaN     NaN
# 2  None Missing      NaN     100.0       NaN      34.0       NaN     NaN
# 3  None Missing      NaN     207.0       NaN     733.0       NaN     NaN
# 4  None Missing      NaN     133.0       NaN     201.0       NaN     NaN
#
#   _frtlt1a _veglt1 _veglt1a    _frt16 _frt16a    _veg23 _veg23a  _fruitex  \
# 0      NaN     NaN      NaN  Included     NaN  Included     NaN  Included
# 1      NaN     NaN      NaN  Included     NaN  Included     NaN  Included
# 2      NaN     NaN      NaN  Included     NaN  Included     NaN  Included
# 3      NaN     NaN      NaN  Included     NaN  Included     NaN  Included
# 4      NaN     NaN      NaN  Included     NaN  Included     NaN  Included
#
#   _fruite1  _vegetex _vegete1  EXERCISE exerany2               _totinda  \
# 0      NaN  Included      NaN       NaN      Yes     PA in past 30 days
# 1      NaN  Included      NaN       NaN       No  No PA in past 30 days
# 2      NaN  Included      NaN       NaN       No  No PA in past 30 days
# 3      NaN  Included      NaN       NaN      Yes     PA in past 30 days
# 4      NaN  Included      NaN       NaN       No  No PA in past 30 days
#
#    exract01  exract11  exeroft1  exerhmm1  exract02  exract21  exeroft2  \
# 0      64.0       NaN     101.0      20.0      88.0       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      28.0       NaN     210.0      30.0      88.0       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    exerhmm2  strength  metval1_  metvl11_  metval2_  metvl21_  actint1_  \
# 0       NaN     201.0      35.0       NaN       0.0       NaN  Moderate
# 1       NaN     888.0       NaN       NaN       NaN       NaN       NaN
# 2       NaN     888.0       NaN       NaN       NaN       NaN       NaN
# 3       NaN     210.0      70.0       NaN       0.0       NaN  Moderate
# 4       NaN     205.0       NaN       NaN       NaN       NaN       NaN
#
#   actin11_                actint2_ actin21_  _minact1  _minac11  _minact2  \
# 0      NaN  No Mod/Vig or Activity      NaN      20.0       NaN       0.0
# 1      NaN                     NaN      NaN       NaN       NaN       NaN
# 2      NaN                     NaN      NaN       NaN       NaN       NaN
# 3      NaN  No Mod/Vig or Activity      NaN      70.0       NaN       0.0
# 4      NaN                     NaN      NaN       NaN       NaN       NaN
#
#    _minac21        pamiss_ pamiss1_  pamin1_  pamin11_  pamin2_  pamin21_  \
# 0       NaN  None Missing       NaN     20.0       NaN      0.0       NaN
# 1       NaN  None Missing       NaN      NaN       NaN      NaN       NaN
# 2       NaN  None Missing       NaN      NaN       NaN      NaN       NaN
# 3       NaN  None Missing       NaN     70.0       NaN      0.0       NaN
# 4       NaN  None Missing       NaN      NaN       NaN      NaN       NaN
#
#    pamin_  pa1min_  pavigm1_  pavig11_  pavigm2_  pavig21_  pavigmn_  \
# 0    20.0      NaN       0.0       NaN       0.0       NaN       0.0
# 1     NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 2     NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 3    70.0      NaN       0.0       NaN       0.0       NaN       0.0
# 4     NaN      NaN       NaN       NaN       NaN       NaN       NaN
#
#    pa1vigm_                 _pacat _pacat1                    _paindex  \
# 0       NaN  Insufficiently Active     NaN  Does not meet Aerobic Recs
# 1       NaN               Inactive     NaN  Does not meet Aerobic Recs
# 2       NaN               Inactive     NaN  Does not meet Aerobic Recs
# 3       NaN  Insufficiently Active     NaN  Does not meet Aerobic Recs
# 4       NaN               Inactive     NaN  Does not meet Aerobic Recs
#
#   _paindx1                            _pa150r1 _pa150r2  \
# 0      NaN  1-149 minutes of physical activity      NaN
# 1      NaN      Zero minutes physical activity      NaN
# 2      NaN      Zero minutes physical activity      NaN
# 3      NaN  1-149 minutes of physical activity      NaN
# 4      NaN      Zero minutes physical activity      NaN
#
#                              _pa300r1 _pa300r2             _pa3002l _pa30021  \
# 0  1-300 minutes of physical activity      NaN  0-300 minutes of PA      NaN
# 1      Zero minutes physical activity      NaN  0-300 minutes of PA      NaN
# 2      Zero minutes physical activity      NaN  0-300 minutes of PA      NaN
# 3  1-300 minutes of physical activity      NaN  0-300 minutes of PA      NaN
# 4      Zero minutes physical activity      NaN  0-300 minutes of PA      NaN
#
#                       _parec _parec1                _pastaer _pastae1  \
# 0  Does not meet either Recs     NaN  Did not meet both Recs      NaN
# 1  Does not meet either Recs     NaN  Did not meet both Recs      NaN
# 2  Does not meet either Recs     NaN  Did not meet both Recs      NaN
# 3        Meets Strength Recs     NaN  Did not meet both Recs      NaN
# 4  Does not meet either Recs     NaN  Did not meet both Recs      NaN
#
#    maxvo2_  fc60_  padur1_  padur2_  pafreq1_  pafreq2_  strfreq_  \
# 0   2810.0  482.0     20.0      NaN    1000.0       NaN     233.0
# 1   3838.0  658.0      NaN      NaN       NaN       NaN       0.0
# 2   4570.0  783.0      NaN      NaN       NaN       NaN       0.0
# 3   4350.0  746.0     30.0      NaN    2333.0       NaN    2333.0
# 4   4900.0  840.0      NaN      NaN       NaN       NaN    1167.0
#
#                       _pastrng  IMMUNE flushot5 flushot6  flshtmy2   imfvplac  \
# 0  Does not meet Strength Recs     NaN       No      NaN       NaN        NaN
# 1  Does not meet Strength Recs     NaN       No      NaN       NaN        NaN
# 2  Does not meet Strength Recs     NaN      Yes      NaN  777777.0  Workplace
# 3          Meets Strength Recs     NaN      Yes      NaN  102010.0      Other
# 4  Does not meet Strength Recs     NaN      Yes      NaN  777777.0     School
#
#   _flshot5 _flshot6 pneuvac3 _pneumo2 tetanus shingle2  HIV_TEST hivtst6  \
# 0      NaN      NaN       DK      NaN     NaN      NaN       NaN      No
# 1      NaN      NaN       DK      NaN     NaN      NaN       NaN     Yes
# 2      NaN      NaN       No      NaN     NaN      NaN       NaN     Yes
# 3      NaN      NaN       No      NaN     NaN      NaN       NaN     Yes
# 4      NaN      NaN       DK      NaN     NaN      NaN       NaN      No
#
#   hivtstd3 whrtst8 whrtst10 hivrisk3 hivrisk4  hivrisk5 _aidtst3  COLOSCRN  \
# 0      NaN     NaN      NaN       No      NaN       NaN       No       NaN
# 1  42005.0     NaN      NaN       No      NaN       NaN      Yes       NaN
# 2  92010.0     NaN      NaN       No      NaN       NaN      Yes       NaN
# 3  72010.0     NaN      NaN       No      NaN       NaN      Yes       NaN
# 4      NaN     NaN      NaN       No      NaN       NaN       No       NaN
#
#   bldstool lstblds3 _rfblds2 _hfob1yr _hfob3yr hadsigm3 hadsgco1 lastsig3  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#   _rfsigm2 _col10yr _fs5yr _fobtfs _crcrec  PROSTATE pcpsaad1 pcpsaad2  \
# 0      NaN      NaN    NaN     NaN     NaN       NaN      NaN      NaN
# 1      NaN      NaN    NaN     NaN     NaN       NaN      NaN      NaN
# 2      NaN      NaN    NaN     NaN     NaN       NaN      NaN      NaN
# 3      NaN      NaN    NaN     NaN     NaN       NaN      NaN      NaN
# 4      NaN      NaN    NaN     NaN     NaN       NaN      NaN      NaN
#
#   pcpsadi1 pcpsare1 psatest1 psatime pcpsars1 _rfpsa21  FEMSCRN hadmam  \
# 0      NaN      NaN      NaN     NaN      NaN      NaN      NaN    NaN
# 1      NaN      NaN      NaN     NaN      NaN      NaN      NaN    NaN
# 2      NaN      NaN      NaN     NaN      NaN      NaN      NaN    NaN
# 3      NaN      NaN      NaN     NaN      NaN      NaN      NaN    NaN
# 4      NaN      NaN      NaN     NaN      NaN      NaN      NaN    NaN
#
#   howlong _rfmam2y _mam502y _mam5021 hadpap2 lastpap2 _rfpap32 _rfpap33  \
# 0     NaN      NaN      NaN      NaN     NaN      NaN      NaN      NaN
# 1     NaN      NaN      NaN      NaN     NaN      NaN      NaN      NaN
# 2     NaN      NaN      NaN      NaN     NaN      NaN      NaN      NaN
# 3     NaN      NaN      NaN      NaN     NaN      NaN      NaN      NaN
# 4     NaN      NaN      NaN      NaN     NaN      NaN      NaN      NaN
#
#   hpvtest hplsttst hadhyst2  MARIJUANA  mjage1st  mjused1st  mjpast30 mjmode1  \
# 0     NaN      NaN      NaN        NaN       NaN        NaN       NaN     NaN
# 1     NaN      NaN      NaN        NaN       NaN        NaN       NaN     NaN
# 2     NaN      NaN      NaN        NaN       NaN        NaN       NaN     NaN
# 3     NaN      NaN      NaN        NaN       NaN        NaN       NaN     NaN
# 4     NaN      NaN      NaN        NaN       NaN        NaN       NaN     NaN
#
#   mjmode2 mjmode3 mjmode4 mjmode5 mjmode6  medmj medmj1 mj_alc mjever mj30day  \
# 0     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN     NaN
#
#    MENTALHEALTH misnervs mishopls misrstls misdeprd miseffrt miswtles  \
# 0           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4           NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    misnowrk mistmnt  mi_score  smi cimemlos  INJURY       seatbelt  \
# 0       NaN     NaN       NaN  NaN      NaN     NaN         Always
# 1       NaN     NaN       NaN  NaN      NaN     NaN  Nearly always
# 2       NaN     NaN       NaN  NaN      NaN     NaN         Always
# 3       NaN     NaN       NaN  NaN      NaN     NaN         Always
# 4       NaN     NaN       NaN  NaN      NaN     NaN         Always
#
#                   _rfseat2    _rfseat3 tsdrivr tsdrove tscpfre tscphnd tstext  \
# 0  Always or almost always      Always     NaN     NaN     NaN     NaN    NaN
# 1  Always or almost always  Not always     NaN     NaN     NaN     NaN    NaN
# 2  Always or almost always      Always     NaN     NaN     NaN     NaN    NaN
# 3  Always or almost always      Always     NaN     NaN     NaN     NaN    NaN
# 4  Always or almost always      Always     NaN     NaN     NaN     NaN    NaN
#
#   tsmjdrv  fall3mn2  fall12mn  fallinj2 firearm4 gunload gununlck loadulk3  \
# 0     NaN       NaN       NaN       NaN      NaN     NaN      NaN      NaN
# 1     NaN       NaN       NaN       NaN      NaN     NaN      NaN      NaN
# 2     NaN       NaN       NaN       NaN      NaN     NaN      NaN      NaN
# 3     NaN       NaN       NaN       NaN      NaN     NaN      NaN      NaN
# 4     NaN       NaN       NaN       NaN      NaN     NaN      NaN      NaN
#
#   not_safe  COMMUNE crfavor crwatch crintvn crreach soclsprt scntmny1  \
# 0      NaN      NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 1      NaN      NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 2      NaN      NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 3      NaN      NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 4      NaN      NaN     NaN     NaN     NaN     NaN      NaN      NaN
#
#   scntmel1  RANDOM_KID rcsbirth rcsgendr  childage rchislat rchisla1 rcsrace  \
# 0      NaN         NaN               NaN       NaN      NaN
# 1      NaN         NaN               NaN       NaN      NaN
# 2      NaN         NaN               NaN       NaN      NaN
# 3      NaN         NaN               NaN       NaN      NaN
# 4      NaN         NaN               NaN       NaN      NaN
#
#   _crace rcsrace1 rcsbrac2 _crace1 rcsrltn2 casthdx2 casthno2 hlthplnc  \
# 0    NaN               NaN     NaN      NaN      NaN      NaN      NaN
# 1    NaN               NaN     NaN      NaN      NaN      NaN      NaN
# 2    NaN               NaN     NaN      NaN      NaN      NaN      NaN
# 3    NaN               NaN     NaN      NaN      NaN      NaN      NaN
# 4    NaN               NaN     NaN      NaN      NaN      NaN      NaN
#
#    IMPUTED _impsex  _impage  _imprace  _impnph   _impcty      _impeduc  \
# 0      NaN     NaN     58.0  White NH      NaN     Clark  College Grad
# 1      NaN     NaN     26.0  White NH      NaN     Clark       HS Grad
# 2      NaN     NaN     26.0  Hispanic      NaN    Kitsap  Some College
# 3      NaN     NaN     30.0  Other NH      NaN  Thurston  College Grad
# 4      NaN     NaN     20.0  Asian NH      NaN      King       HS Grad
#
#                _impmrtl _imphome                  msacode1 mscode  WEIGHTS  \
# 0              Divorced    Other        Vancouver-Portland    NaN      NaN
# 1  Member Unmarried Cpl     Rent        Vancouver-Portland    NaN      NaN
# 2  Member Unmarried Cpl     Rent      Bremerton/Silverdale    NaN      NaN
# 3               Married      Own                   Olympia    NaN      NaN
# 4         Never Married      Own  Seattle-Bellevue-Everett    NaN      NaN
#
#        _llcpwt     wallcpwt   wallcpwt_a       use_wt    use_comb  \
# 0   859.029484   799.071113   791.611951   799.071106  124.255562
# 1  2270.553130  2085.626841  2158.511723  2085.626953  324.314972
# 2  1997.038308  1891.299571  1977.598413  1891.299561  294.097076
# 3  1124.844034   966.681657  1070.038706   966.681641  150.319000
# 4  2700.356883  2769.760773  3283.853291  2769.760742  430.697815
#
#         pot_wt    pot_comb     wt_odds  wt_evens  fire_wt  _cllcpwt  \
# 0   791.611938   92.301956   33.163811       NaN      NaN       NaN
# 1  2158.511719  251.682465   86.559669       NaN      NaN       NaN
# 2  1977.598389  230.587982   78.494507       NaN      NaN       NaN
# 3  1070.038696  124.766510   40.120140       NaN      NaN       NaN
# 4  3283.853271  382.897308  114.953247       NaN      NaN       NaN
#
#    wallcpwt_ch  use_kid agestd  agestdwt agestd2  agestwt2
# 0          NaN      NaN  45-64  0.299194   45-64  0.343431
# 1          NaN      NaN  25-34  0.182648   25-34  0.209654
# 2          NaN      NaN  25-34  0.182648   25-34  0.209654
# 3          NaN      NaN  25-34  0.182648   25-34  0.209654
# 4          NaN      NaN  18-24  0.128810     NaN       NaN

# %%
test['employ'].value_counts()
# Out:
# Employed for wages     11528
# Retired                 9394
# Self-employed           2448
# Homemaker               2132
# Unable  to work         1882
# Unemployed 1+ years     1027
# Unemployed < 1 year      863
# Student                  667
# Refused                  109
# Name: employ, dtype: int64

# %%
test['employ1'].value_counts()
# Out:
# Employed for wages     25842
# Retired                20864
# Self-employed           5121
# Homemaker               4002
# Unable  to work         3885
# Student                 1783
# Unemployed 1+ years     1494
# Unemployed < 1 year     1391
# Refused                  478
# Name: employ1, dtype: int64

# %%
# %run -i main.py

# %%
df.tail()
# Out:
#          Age   Race   Income  Over Median Income Ownership  Household Size  \
# 54761  75-79  White  $50-75K               False       Own             2.0
# 7040   60-64  White  $50-75K               False       Own             1.0
# 59449  45-49  White     $75+                True       Own             3.0
# 56812  40-44  White     $75+                True       Own             7.0
# 7389   55-59  White  $25-35K               False       Own             1.0
#
#        Zip-code  In Food Desert          Employment  \
# 54761   98846.0           False             Unknown
# 7040    98201.0           False  Employed for wages
# 59449   98003.0           False             Unknown
# 56812   98033.0           False             Unknown
# 7389    98225.0           False  Employed for wages
#
#                            Active Overweight  Pre-Diabetic Good-health  \
# 54761                     Unknown       Over         False        Fair
# 7040           Meets Aerobic Recs      Obese         False        Good
# 59449                     Unknown      Obese         False        Good
# 56812                     Unknown       Over         False   Very Good
# 7389   Does not meet Aerobic Recs       Over         False        Fair
#
#        No Veg  No Fruit  Fruit Daily  Veg Daily  Fruit Weekly  Veg Weekly  \
# 54761   False     False         True       True         False       False
# 7040    False     False        False      False         False       False
# 59449   False     False        False       True         False       False
# 56812   False     False         True       True         False       False
# 7389    False     False        False      False         False       False
#
#        Fruit Monthly  Veg Monthly  Sleep_hrs Insurance Dr_too_much  \
# 54761          False        False        NaN   Missing          No
# 7040            True         True        NaN       Yes          No
# 59449           True        False        NaN       Yes          No
# 56812          False        False        NaN       Yes          No
# 7389           False         True        NaN        No         Yes
#
#       Recent_Dr_visit               Smoker Alcohol
# 54761       Past Year         Never Smoked     nan
# 7040        Past Year        Former Smoker     nan
# 59449       1-2 years         Never Smoked     nan
# 56812       2-5 years         Never Smoked   other
# 7389         5+ years  Current - Some Days     nan

# %%
df['Pre-Diabetic'] = df['Pre-Diabetic'].astype(int)
df.describe()
# Out:
#        Household Size      Zip-code  Pre-Diabetic    Sleep_hrs
# count    35088.000000  35091.000000  35091.000000  7241.000000
# mean         2.380728  98350.379528      0.071386     7.095981
# std          1.405266    270.493231      0.257472     1.291830
# min          1.000000  98001.000000      0.000000     2.000000
# 25%          1.000000  98112.000000      0.000000     6.000000
# 50%          2.000000  98290.000000      0.000000     7.000000
# 75%          3.000000  98579.000000      0.000000     8.000000
# max         18.000000  98953.000000      1.000000    18.000000

# %%
def train_val_test_split(X, y):
    trainval, test, y_trainval, y_test = train_test_split(X,
                                                          y,
                                                          stratify=y,
                                                          random_state=42,
                                                          )
    train, val, y_train, y_val = train_test_split(trainval,
                                                 y_trainval,
                                                 stratify=y_trainval,
                                                 random_state=42)
    return train, val, test, y_train, y_val, y_test

# %%
target = 'Pre-Diabetic'
y = df[target].astype(int)
X = df.drop(columns=target)

# %%
train, val, test, y_train, y_val, y_test = train_val_test_split(X, y)
train.shape, val.shape, test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((19738, 26), (6580, 26), (8773, 26), (19738,), (6580,), (8773,))

# %%
# Predict majority class as baseline.
y.value_counts(normalize=True)
# Out:
# 0    0.928614
# 1    0.071386
# Name: Pre-Diabetic, dtype: float64

# %%
roc_auc_score(y_train, np.full(y_train.shape, 0))
# Out:
# 0.5

# %%
pipeline = make_pipeline(OrdinalEncoder(),
                         SimpleImputer())

# %%
X_train = pipeline.fit_transform(train)
X_val = pipeline.transform(val)
X_test = pipeline.transform(test)
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((19738, 26), (6580, 26), (8773, 26))

# %%
eval_set = [(X_train, y_train),
            (X_val, y_val)]

# %%
model = XGBRFClassifier(n_jobs=-1,
                        n_estimators=5000,
                        early_stopping_rounds=50,
                        random_state=42,
                        scale_pos_weight=10,
                        learning_rate=.01,
                        verbosity=2)

# %%
model.fit(X_train,
          y_train,
          eval_set=eval_set,
          eval_metric='auc',
          verbose=True)
# Out:
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:45] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# ...
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [00:11:46] INFO: src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]	validation_0-auc:0.71667	validation_1-auc:0.696041
# XGBRFClassifier(base_score=0.5, colsample_bylevel=1, colsample_bynode=0.8,
#                 colsample_bytree=1, early_stopping_rounds=50, gamma=0,
#                 learning_rate=0.01, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=5000, n_jobs=-1,
#                 nthread=None, objective='binary:logistic', random_state=42,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=10, seed=None,
#                 silent=None, subsample=0.8, verbosity=3)

# %%
y_pred_proba = model.predict_proba(X_val)[:, 1]
print(f'Validation ROC AUC score: {roc_auc_score(y_val, y_pred_proba)}')
curve = roc_curve(y_val, y_pred_proba)[1]
x_ = np.linspace(0, 1, len(curve))
fig = plt.figure(figsize=(6, 6))
ax = fig.gca()
y_ = x_
plt.plot(x_, curve, label='Model Preditions')
plt.plot(x_, y_, color='red', label='Baseline')
plt.title('True Positive Rate by Prediction Probability Threshold.',
          fontsize=16,
          color='white')
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('Probability Threshold for Positive Prediction')
plt.legend();
# Out:
# Validation ROC AUC score: 0.6960408468851204

# %%
permuter = PermutationImportance(model,
                                 cv='prefit',
                                 n_iter=5,
                                 scoring='roc_auc',
                                 random_state=42)
permuter.fit(X_val, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=XGBRFClassifier(base_score=0.5,
#                                                 colsample_bylevel=1,
#                                                 colsample_bynode=0.8,
#                                                 colsample_bytree=1,
#                                                 early_stopping_rounds=50,
#                                                 gamma=0, learning_rate=0.01,
#                                                 max_delta_step=0, max_depth=3,
#                                                 min_child_weight=1,
#                                                 missing=None, n_estimators=5000,
#                                                 n_jobs=-1, nthread=None,
#                                                 objective='binary:logistic',
#                                                 random_state=42, reg_alpha=0,
#                                                 reg_lambda=1,
#                                                 scale_pos_weight=10, seed=None,
#                                                 silent=None, subsample=0.8,
#                                                 verbosity=1),
#                       n_iter=5, random_state=42, refit=True, scoring='roc_auc')

# %%
features_of_import = pd.Series(permuter.feature_importances_, val.columns)
plt.figure(figsize=(8, len(val.columns) / 2))
features_of_import.sort_values(ascending=True).plot.barh();

# %%
importance = pd.Series(model.feature_importances_, val.columns)
plt.figure(figsize=(8, len(val.columns) / 2))
importance.sort_values(ascending=True).plot.barh()

# %%
model1 = RandomForestClassifier(n_estimators=500,
                                n_jobs=-1,
                                random_state=42)
model1.fit(X_train, y_train, )
y_pred_proba1 = model1.predict_proba(X_val)[:, 1]
print(f'RandomForestClassifier ROC AUC: {roc_auc_score(y_val, y_pred_proba1)}')
# Out:
# RandomForestClassifier ROC AUC: 0.6674325312532646

# %%
model2 = XGBClassifier(n_jobs=-1,
                       n_estimators=5000,
                       early_stopping_rounds=50,
                       random_state=42,
                       verbosity=0,
                       )
model2.fit(X_train, y_train, eval_set=eval_set, verbose=False, eval_metric='auc')
y_pred_proba2 = model2.predict_proba(X_val)[:, 1]
print(f'XGBClassifier ROC AUC: {roc_auc_score(y_val, y_pred_proba2)}')
# Out:
# XGBClassifier ROC AUC: 0.6623397290803357
